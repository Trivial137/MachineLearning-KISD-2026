# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/MachineLearning-KISD-2026/blob/main/lecture5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
#
#
#
# #**<font color = "red">Introduction to machine learning</font>**
#
# **Lecture 5**
#
#
#
# ##**<font color = "green">Transfer learning</font>**
# ##**<font color = "green">Cross-validation</font>**
# ##**<font color = "green">Hyper-parameter tuning</font>**
#
#
# *1 April 2026*
#
#
# ---
#
# *Marcin Wolter, IFJ PAN*
#
# *e-mail: marcin.wolter@ifj.edu.pl*
#
#
# ---
# </center>

# %% [markdown]
# #<font color='green'>**Program for today:**
#
# * ###  <font color='red'>How much Deep Neaural Networks can improve physics analysis?
#
# ---
#
# * ###  <font color='red'>Use knowlegdge from previous trainings - knowlegde transfer by using pretrained networks
# * ###  <font color='red'>Cross-validation, k-folding - using all data for training
# * ###  <font color='red'>Hyperparameter optimization
#
#
# ---
#
#
#
#
#
# <br>
#
#
# **As always all slides are here:**
#
# *https://github.com/marcinwolter/MachineLearning-KISD-2026*
#
# <br>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # <font color='green'> **How much DNN can improve High Energy Physics analysis?**
#
# **A well known paper by P. Baldi, P.Sadowski and D. Whiteson**
#
# https://www.nature.com/articles/ncomms5308.pdf

# %% [markdown]
# <center>
#
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_56.png' width=650px>
# <br>
#
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_57.png' width=350px>
# <br>
#
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_58.png' width=450px>
# <br>
#
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_59.png' width=450px>
# <br>
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_510.png' width=450px>
# <br>
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_511.png' width=450px>
# <br>
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_512.png' width=450px>
# <br>
#
# <img src = 'https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture5_2023/MachineLearning2018_513.png' width=550px>
# <br>
#
#
#
# ---
#
#
# # <font color='red'> **Significantly better performance with Deep Learning!!!**

# %% [markdown]
# ### **An iPython notebook**
# "repeating" to some extend the analysis from the above article:
#
# https://github.com/marcinwolter/MachineLearning-KISD-2025/blob/main/HIGGS.ipynb
#
# The notebook reuires some resources - most probably it will not complete on the free google colab.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# <center>
#
# # <font color='green'> **Data augmentation**

# %% [markdown]
# #**How to improve the performance?**
#
# From last week example we have learned, that the methods are:
# * Train more networks in parallel and take an average as a clissifier,
# * Artificially increase the size of the training dataset - <font color='red'> **create more images by the *augmentation* procedure.**

# %% [markdown]
# #**Data augmentation**
# in data analysis are techniques used to increase the amount of data by adding slightly modified copies of already existing data or newly created synthetic data from existing data. It acts as a regularizer and helps reduce overfitting when training a machine learning model.
#
# ###**Transformations of images**
#
# Geometric transformations, flipping, color modification, cropping, rotation, noise injection and random erasing are used to augment image in deep learning.
#
# ###**Introducing new synthetic images**
# If a dataset is very small, then a version augmented with rotation and mirroring etc. may still not be enough for a given problem. Another solution is the sourcing of entirely new, synthetic images through various techniques, for example the use of **generative adversarial networks** *(we will talk about them later)* to create new synthetic images for data augmentation.
#
# <br>
#
# *Shorten, Connor; Khoshgoftaar, Taghi M. (2019). "[A survey on Image Data Augmentation for Deep Learning](https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0)". Mathematics and Computers in Simulation. springer. 6: 60. doi:10.1186/s40537-019-0197-0*

# %% [markdown]
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture7/data_aug_basic.png' width=650px>
#
# <br>
#
# ---
#
# <br>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture7/1_kqKzGryy0qYjEXbR3kyNOg.png' width=650px>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # <font color='green'>**An example – pattern recognition**
# # <font color='green'>**on CIFAR10 photos dataset**
#
# **CIFAR10** small image classification. <br>Dataset of 50\,000 32x32 color training images\, labeled over 10 categories\, and 10\,000 test images\.</span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture7/MachineLearning2020_733.png' width=450px>
#
#
#
# **Augmentation:**<br>
# the network is trained with and without augmentation.
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture7/MachineLearning2020_734.png' width=450px>

# %% [markdown]
# # Modified version of:
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb

# %% [markdown]
# ### CNN with Image Augmentation (CIFAR10)
# images of 10 categories: airplane, automobile, bird, cat, deer, dog, frog, horse, ship and truck. In RGB, 32x32 pixels.
#
# **The state of the art accuracy is about 99 percent.**
#
# We will NOT reach such a high accuracy...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras as k
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from keras.regularizers import l2
import h5py
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### **Important:** we reduce number or training images taking 5 classes out of 10 and reducing the size of training dataset
#
# This is done to make the training faster. You can try training un the full dataset.

# %%
 # labels
num_classes=5

#load data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_rows, img_cols , channels = 32,32,3

# REDUCE THE SIZE OF TRAINING SAMPLE TO 30 000 events
x_train = x_train[0:30000]
y_train = y_train[0:30000]

# take some labels only
x_train = x_train[np.where(y_train.reshape(-1)<num_classes)]
y_train = y_train[np.where(y_train.reshape(-1)<num_classes)]
x_test = x_test[np.where(y_test.reshape(-1)<num_classes)]
y_test = y_test[np.where(y_test.reshape(-1)<num_classes)]

# save x_test images
xx_test = x_test
yy_test = y_test

fig = plt.figure(figsize=(12, 12))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.axis('off')
    plt.imshow(x_train[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
#reshape into images
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
input_shape = (img_rows, img_cols, 1)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (15020, 32, 32, 3)
# 15020 train samples
# 5000 test samples

# %%
#convert integers to float; normalise and center the mean
x_train=x_train.astype("float32")
x_test=x_test.astype("float32")
mean=np.mean(x_train)
std=np.std(x_train)
x_test=(x_test-mean)/std
x_train=(x_train-mean)/std

# %%
print(y_train.shape)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test  = tf.keras.utils.to_categorical(y_test, num_classes)
print(y_train.shape)
# Out:
# (15020, 1)
# (15020, 5)

# %%
# build and compile the model


reg=None
num_filters=32
ac='relu'
#adm=tf.keras.optimizers.legacy.Adam(learning_rate=0.001, decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
# Use the standard Adam optimizer from keras.optimizers:
from tensorflow.keras.optimizers import Adam

opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

drop_dense=0.5
drop_conv=0.1

model = Sequential()

model.add(Conv2D(num_filters, (3, 3), activation=ac, kernel_regularizer=reg, input_shape=(img_rows, img_cols, channels),padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 16x16x3xnum_filters
model.add(Dropout(drop_conv))

model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 8x8x3x(2*num_filters)
model.add(Dropout(drop_conv))

model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 4x4x3x(4*num_filters)
model.add(Dropout(drop_conv))

model.add(Flatten())
model.add(Dense(512, activation=ac,kernel_regularizer=reg))
model.add(BatchNormalization())
model.add(Dropout(drop_dense))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,342,501 (5.12 MB)
#  Trainable params: 1,340,581 (5.11 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# #**Training without augmentation**

# %%
# training without augmentation
history=model.fit(x_train, y_train, batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 26s 102ms/step - accuracy: 0.5611 - loss: 1.2660 - val_accuracy: 0.2560 - val_loss: 2.1046
# Epoch 2/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6787 - loss: 0.8537 - val_accuracy: 0.4560 - val_loss: 1.7180
# Epoch 3/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7353 - loss: 0.7049 - val_accuracy: 0.6278 - val_loss: 0.9815
# Epoch 4/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7767 - loss: 0.5979 - val_accuracy: 0.7458 - val_loss: 0.6742
# Epoch 5/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8089 - loss: 0.5097 - val_accuracy: 0.7858 - val_loss: 0.5646
# Epoch 6/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8311 - loss: 0.4524 - val_accuracy: 0.7758 - val_loss: 0.6132
# Epoch 7/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8525 - loss: 0.3940 - val_accuracy: 0.8086 - val_loss: 0.5696
# Epoch 8/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8760 - loss: 0.3328 - val_accuracy: 0.7900 - val_loss: 0.6307
# Epoch 9/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8887 - loss: 0.3003 - val_accuracy: 0.7946 - val_loss: 0.5903
# Epoch 10/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9039 - loss: 0.2589 - val_accuracy: 0.8088 - val_loss: 0.5876
# Epoch 11/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9219 - loss: 0.2111 - val_accuracy: 0.8168 - val_loss: 0.6059
# Epoch 12/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9300 - loss: 0.1904 - val_accuracy: 0.8094 - val_loss: 0.6321
# Epoch 13/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9403 - loss: 0.1628 - val_accuracy: 0.8202 - val_loss: 0.6428
# Epoch 14/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9439 - loss: 0.1529 - val_accuracy: 0.8164 - val_loss: 0.6621
# Epoch 15/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9439 - loss: 0.1522 - val_accuracy: 0.8178 - val_loss: 0.6800
# Epoch 16/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9581 - loss: 0.1149 - val_accuracy: 0.8194 - val_loss: 0.6697
# Epoch 17/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9627 - loss: 0.1016 - val_accuracy: 0.7992 - val_loss: 0.8439
# Epoch 18/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9553 - loss: 0.1203 - val_accuracy: 0.8022 - val_loss: 0.7952
# Epoch 19/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9676 - loss: 0.0920 - val_accuracy: 0.8224 - val_loss: 0.7218
# Epoch 20/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9657 - loss: 0.0946 - val_accuracy: 0.8100 - val_loss: 0.7319
# Epoch 21/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9704 - loss: 0.0791 - val_accuracy: 0.8250 - val_loss: 0.7908
# Epoch 22/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9688 - loss: 0.0861 - val_accuracy: 0.8176 - val_loss: 0.7594
# Epoch 23/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9726 - loss: 0.0748 - val_accuracy: 0.8172 - val_loss: 0.7905
# Epoch 24/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9746 - loss: 0.0707 - val_accuracy: 0.8260 - val_loss: 0.7533
# Epoch 25/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9764 - loss: 0.0643 - val_accuracy: 0.8200 - val_loss: 0.8337
# Epoch 26/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9806 - loss: 0.0564 - val_accuracy: 0.8304 - val_loss: 0.7750
# Epoch 27/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9830 - loss: 0.0505 - val_accuracy: 0.8296 - val_loss: 0.8012
# Epoch 28/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9778 - loss: 0.0629 - val_accuracy: 0.8238 - val_loss: 0.8278
# Epoch 29/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9802 - loss: 0.0557 - val_accuracy: 0.8316 - val_loss: 0.7796
# Epoch 30/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9751 - loss: 0.0742 - val_accuracy: 0.8268 - val_loss: 0.8110
# Epoch 31/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9775 - loss: 0.0642 - val_accuracy: 0.8362 - val_loss: 0.7383
# Epoch 32/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9766 - loss: 0.0666 - val_accuracy: 0.8284 - val_loss: 0.7728
# Epoch 33/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9802 - loss: 0.0586 - val_accuracy: 0.8306 - val_loss: 0.7922
# Epoch 34/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9814 - loss: 0.0500 - val_accuracy: 0.8232 - val_loss: 0.8398
# Epoch 35/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9836 - loss: 0.0461 - val_accuracy: 0.8346 - val_loss: 0.7643
# Epoch 36/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9875 - loss: 0.0321 - val_accuracy: 0.8392 - val_loss: 0.7765
# Epoch 37/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9870 - loss: 0.0373 - val_accuracy: 0.8392 - val_loss: 0.8065
# Epoch 38/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9846 - loss: 0.0438 - val_accuracy: 0.8330 - val_loss: 0.8108
# Epoch 39/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9814 - loss: 0.0531 - val_accuracy: 0.8372 - val_loss: 0.7911
# Epoch 40/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9771 - loss: 0.0633 - val_accuracy: 0.8260 - val_loss: 0.8215
# Epoch 41/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9840 - loss: 0.0448 - val_accuracy: 0.8280 - val_loss: 0.8463
# Epoch 42/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9864 - loss: 0.0430 - val_accuracy: 0.8490 - val_loss: 0.7649
# Epoch 43/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9880 - loss: 0.0341 - val_accuracy: 0.8396 - val_loss: 0.8113
# Epoch 44/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9883 - loss: 0.0360 - val_accuracy: 0.8394 - val_loss: 0.8197
# Epoch 45/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9899 - loss: 0.0302 - val_accuracy: 0.8454 - val_loss: 0.7786
# Epoch 46/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9870 - loss: 0.0364 - val_accuracy: 0.8338 - val_loss: 0.8759
# Epoch 47/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9836 - loss: 0.0467 - val_accuracy: 0.8358 - val_loss: 0.8469
# Epoch 48/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9854 - loss: 0.0415 - val_accuracy: 0.8336 - val_loss: 0.8232
# Epoch 49/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9862 - loss: 0.0375 - val_accuracy: 0.8418 - val_loss: 0.8030
# Epoch 50/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9897 - loss: 0.0302 - val_accuracy: 0.8368 - val_loss: 0.8606
# Epoch 51/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9894 - loss: 0.0306 - val_accuracy: 0.8274 - val_loss: 0.8870
# Epoch 52/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9902 - loss: 0.0284 - val_accuracy: 0.8388 - val_loss: 0.8676
# Epoch 53/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9858 - loss: 0.0430 - val_accuracy: 0.8352 - val_loss: 0.8928
# Epoch 54/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9865 - loss: 0.0406 - val_accuracy: 0.8382 - val_loss: 0.8303
# Epoch 55/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9860 - loss: 0.0407 - val_accuracy: 0.8422 - val_loss: 0.8360
# Epoch 56/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9903 - loss: 0.0301 - val_accuracy: 0.8398 - val_loss: 0.8799
# Epoch 57/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9891 - loss: 0.0298 - val_accuracy: 0.8432 - val_loss: 0.8909
# Epoch 58/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9920 - loss: 0.0226 - val_accuracy: 0.8318 - val_loss: 0.9447
# Epoch 59/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9913 - loss: 0.0255 - val_accuracy: 0.8418 - val_loss: 0.9583
# Epoch 60/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9913 - loss: 0.0250 - val_accuracy: 0.8418 - val_loss: 0.9380
# Epoch 61/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9913 - loss: 0.0239 - val_accuracy: 0.8396 - val_loss: 0.9156
# Epoch 62/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9901 - loss: 0.0287 - val_accuracy: 0.8404 - val_loss: 0.9533
# Epoch 63/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9885 - loss: 0.0356 - val_accuracy: 0.8358 - val_loss: 0.9814
# Epoch 64/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9897 - loss: 0.0311 - val_accuracy: 0.8478 - val_loss: 0.8601
# Epoch 65/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9915 - loss: 0.0244 - val_accuracy: 0.8468 - val_loss: 0.8425
# Epoch 66/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9911 - loss: 0.0274 - val_accuracy: 0.8480 - val_loss: 0.8474
# Epoch 67/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9920 - loss: 0.0232 - val_accuracy: 0.8432 - val_loss: 0.8540
# Epoch 68/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9932 - loss: 0.0213 - val_accuracy: 0.8454 - val_loss: 0.9119
# Epoch 69/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9938 - loss: 0.0179 - val_accuracy: 0.8474 - val_loss: 0.8986
# Epoch 70/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9927 - loss: 0.0215 - val_accuracy: 0.8418 - val_loss: 0.9286
# Epoch 71/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9906 - loss: 0.0283 - val_accuracy: 0.8476 - val_loss: 0.8757
# Epoch 72/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9923 - loss: 0.0222 - val_accuracy: 0.8466 - val_loss: 0.9001
# Epoch 73/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9917 - loss: 0.0225 - val_accuracy: 0.8352 - val_loss: 0.9734
# Epoch 74/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9907 - loss: 0.0295 - val_accuracy: 0.8310 - val_loss: 0.9942
# Epoch 75/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9895 - loss: 0.0315 - val_accuracy: 0.8398 - val_loss: 0.9268
# Epoch 76/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9895 - loss: 0.0323 - val_accuracy: 0.8376 - val_loss: 0.9626
# Epoch 77/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9915 - loss: 0.0246 - val_accuracy: 0.8304 - val_loss: 0.9894
# Epoch 78/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9927 - loss: 0.0214 - val_accuracy: 0.8516 - val_loss: 0.8702
# Epoch 79/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9931 - loss: 0.0184 - val_accuracy: 0.8480 - val_loss: 0.8831
# Epoch 80/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9929 - loss: 0.0210 - val_accuracy: 0.8460 - val_loss: 0.9068
# Epoch 81/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9929 - loss: 0.0214 - val_accuracy: 0.8392 - val_loss: 0.9379
# Epoch 82/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9915 - loss: 0.0261 - val_accuracy: 0.8332 - val_loss: 1.0152
# Epoch 83/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9945 - loss: 0.0161 - val_accuracy: 0.8478 - val_loss: 0.9085
# Epoch 84/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9921 - loss: 0.0235 - val_accuracy: 0.8426 - val_loss: 0.9564
# Epoch 85/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0338 - val_accuracy: 0.8452 - val_loss: 0.9226
# Epoch 86/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9933 - loss: 0.0197 - val_accuracy: 0.8416 - val_loss: 0.9867
# Epoch 87/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9920 - loss: 0.0217 - val_accuracy: 0.8436 - val_loss: 0.9064
# Epoch 88/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9948 - loss: 0.0149 - val_accuracy: 0.8548 - val_loss: 0.9047
# Epoch 89/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9947 - loss: 0.0157 - val_accuracy: 0.8446 - val_loss: 0.9321
# Epoch 90/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9897 - loss: 0.0295 - val_accuracy: 0.8376 - val_loss: 0.9969
# Epoch 91/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9911 - loss: 0.0240 - val_accuracy: 0.8448 - val_loss: 0.9860
# Epoch 92/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9931 - loss: 0.0187 - val_accuracy: 0.8468 - val_loss: 0.9351
# Epoch 93/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9932 - loss: 0.0194 - val_accuracy: 0.8420 - val_loss: 0.9960
# Epoch 94/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9937 - loss: 0.0178 - val_accuracy: 0.8526 - val_loss: 0.9683
# Epoch 95/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9932 - loss: 0.0211 - val_accuracy: 0.8426 - val_loss: 0.9822
# Epoch 96/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9914 - loss: 0.0265 - val_accuracy: 0.8412 - val_loss: 1.0023
# Epoch 97/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9915 - loss: 0.0267 - val_accuracy: 0.8502 - val_loss: 0.9243
# Epoch 98/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9928 - loss: 0.0204 - val_accuracy: 0.8436 - val_loss: 0.9520
# Epoch 99/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9937 - loss: 0.0184 - val_accuracy: 0.8440 - val_loss: 0.9999
# Epoch 100/100
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9946 - loss: 0.0159 - val_accuracy: 0.8552 - val_loss: 0.9151

# %%
#training and test accuracy without dropout
train_acc=model.evaluate(x_train,y_train,batch_size=128)
train_acc

test_acc=model.evaluate(x_test,y_test,batch_size=128)
test_acc

print("Training accuracy: ", train_acc[1])
print("Testing accuracy: ", test_acc[1])
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9997 - loss: 0.0014
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8552 - loss: 0.9151
# Training accuracy:  0.9996671080589294
# Testing accuracy:  0.8551999926567078

# %%
# plotting helper function
def plothist(hist):
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plothist(history)

# %%
#model.save('cifar10_01.h5')
#model=load_model('cifar10_01.h5')

# %% [markdown]
# #**Build bigger network, train with augmentation!**

# %% [markdown]
# # **Here comes the augmentation**

# %%
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.25
    )
datagen.fit(x_train)

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow((X_batch[i]*std+mean).astype(np.uint8))    # again convert beack to integers
         plt.axis('off')
    plt.show()
    break

# %% [markdown]
# Augmentation of a single image

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[1:3], y_train[1:3], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow((X_batch[0]*std+mean).astype(np.uint8))
         plt.axis('off')
         break

plt.show()

# %%
# build again, same model as model1

#reg=l2(1e-4)   # L2 or "ridge" regularisation
reg2=None
num_filters2=32
ac2='relu'
# Use the standard Adam optimizer from keras.optimizers:
from tensorflow.keras.optimizers import Adam

opt2 = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

drop_dense2=0.5
drop_conv2=0.1

model2 = Sequential()

model2.add(Conv2D(num_filters2, (3, 3), activation=ac2, kernel_regularizer=reg2, input_shape=(img_rows, img_cols, channels),padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(Conv2D(num_filters2, (3, 3), activation=ac2,kernel_regularizer=reg2,padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 16x16x3xnum_filters
model2.add(Dropout(drop_conv2))

model2.add(Conv2D(2*num_filters2, (3, 3), activation=ac2,kernel_regularizer=reg2,padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(Conv2D(2*num_filters2, (3, 3), activation=ac2,kernel_regularizer=reg2,padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 8x8x3x(2*num_filters)
model2.add(Dropout(drop_conv2))

model2.add(Conv2D(4*num_filters2, (3, 3), activation=ac2,kernel_regularizer=reg2,padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(Conv2D(4*num_filters2, (3, 3), activation=ac2,kernel_regularizer=reg2,padding='same'))
model2.add(BatchNormalization(axis=-1))
model2.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 4x4x3x(4*num_filters)
model2.add(Dropout(drop_conv2))

model2.add(Flatten())
model2.add(Dense(512, activation=ac2,kernel_regularizer=reg2))
model2.add(BatchNormalization())
model2.add(Dropout(drop_dense2))
model2.add(Dense(num_classes, activation='softmax'))

model2.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt2)

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,342,501 (5.12 MB)
#  Trainable params: 1,340,581 (5.11 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# #**Training with augmentation (using *datagen.flow*)**

# %%
# train with image augmentation
history2=model2.fit(datagen.flow(x_train, y_train, batch_size=128),
                    steps_per_epoch = int(len(x_train) / 128), epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - accuracy: 0.4719 - loss: 1.5370 - val_accuracy: 0.2452 - val_loss: 2.1854
# Epoch 2/100
#   1/117 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5938 - loss: 1.3045
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5938 - loss: 1.3045 - val_accuracy: 0.2384 - val_loss: 2.1840
# Epoch 3/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.5704 - loss: 1.1316 - val_accuracy: 0.2994 - val_loss: 2.2932
# Epoch 4/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5625 - loss: 1.1561 - val_accuracy: 0.3014 - val_loss: 2.2476
# Epoch 5/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6048 - loss: 1.0170 - val_accuracy: 0.5026 - val_loss: 1.2745
# Epoch 6/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6094 - loss: 1.0977 - val_accuracy: 0.5050 - val_loss: 1.2665
# Epoch 7/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.6379 - loss: 0.9453 - val_accuracy: 0.6796 - val_loss: 0.7942
# Epoch 8/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6484 - loss: 0.8948 - val_accuracy: 0.6800 - val_loss: 0.7885
# Epoch 9/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6594 - loss: 0.8818 - val_accuracy: 0.7104 - val_loss: 0.7591
# Epoch 10/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.8759 - val_accuracy: 0.7064 - val_loss: 0.7621
# Epoch 11/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6839 - loss: 0.8192 - val_accuracy: 0.6854 - val_loss: 0.8636
# Epoch 12/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6328 - loss: 0.8977 - val_accuracy: 0.6912 - val_loss: 0.8360
# Epoch 13/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.6938 - loss: 0.7936 - val_accuracy: 0.6952 - val_loss: 0.8053
# Epoch 14/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6953 - loss: 0.8542 - val_accuracy: 0.7010 - val_loss: 0.7992
# Epoch 15/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7070 - loss: 0.7671 - val_accuracy: 0.7232 - val_loss: 0.7791
# Epoch 16/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6875 - loss: 0.7416 - val_accuracy: 0.7262 - val_loss: 0.7748
# Epoch 17/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.7163 - loss: 0.7355 - val_accuracy: 0.7592 - val_loss: 0.6639
# Epoch 18/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.6687 - val_accuracy: 0.7720 - val_loss: 0.6218
# Epoch 19/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7340 - loss: 0.7062 - val_accuracy: 0.7814 - val_loss: 0.5902
# Epoch 20/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6562 - loss: 0.7039 - val_accuracy: 0.7806 - val_loss: 0.5976
# Epoch 21/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.7372 - loss: 0.6879 - val_accuracy: 0.7928 - val_loss: 0.5555
# Epoch 22/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7109 - loss: 0.7062 - val_accuracy: 0.7912 - val_loss: 0.5542
# Epoch 23/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.7543 - loss: 0.6563 - val_accuracy: 0.7674 - val_loss: 0.6519
# Epoch 24/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7344 - loss: 0.6768 - val_accuracy: 0.7666 - val_loss: 0.6595
# Epoch 25/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - accuracy: 0.7544 - loss: 0.6379 - val_accuracy: 0.7546 - val_loss: 0.7213
# Epoch 26/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7266 - loss: 0.8782 - val_accuracy: 0.7532 - val_loss: 0.7148
# Epoch 27/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7675 - loss: 0.6215 - val_accuracy: 0.7508 - val_loss: 0.7385
# Epoch 28/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7188 - loss: 0.6445 - val_accuracy: 0.7462 - val_loss: 0.7604
# Epoch 29/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.7652 - loss: 0.6177 - val_accuracy: 0.7838 - val_loss: 0.6220
# Epoch 30/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8281 - loss: 0.5220 - val_accuracy: 0.7956 - val_loss: 0.5794
# Epoch 31/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7726 - loss: 0.6037 - val_accuracy: 0.7968 - val_loss: 0.5793
# Epoch 32/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8047 - loss: 0.5544 - val_accuracy: 0.7944 - val_loss: 0.5748
# Epoch 33/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.7850 - loss: 0.5716 - val_accuracy: 0.8186 - val_loss: 0.4950
# Epoch 34/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7266 - loss: 0.7407 - val_accuracy: 0.8154 - val_loss: 0.5005
# Epoch 35/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7850 - loss: 0.5689 - val_accuracy: 0.8296 - val_loss: 0.4750
# Epoch 36/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8047 - loss: 0.6161 - val_accuracy: 0.8250 - val_loss: 0.4793
# Epoch 37/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.7919 - loss: 0.5525 - val_accuracy: 0.8032 - val_loss: 0.5437
# Epoch 38/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.4834 - val_accuracy: 0.8042 - val_loss: 0.5438
# Epoch 39/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - accuracy: 0.7946 - loss: 0.5409 - val_accuracy: 0.8172 - val_loss: 0.5527
# Epoch 40/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8594 - loss: 0.4627 - val_accuracy: 0.8170 - val_loss: 0.5529
# Epoch 41/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8014 - loss: 0.5276 - val_accuracy: 0.8458 - val_loss: 0.4285
# Epoch 42/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8359 - loss: 0.4183 - val_accuracy: 0.8426 - val_loss: 0.4377
# Epoch 43/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8086 - loss: 0.5099 - val_accuracy: 0.8386 - val_loss: 0.4620
# Epoch 44/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3421 - val_accuracy: 0.8390 - val_loss: 0.4588
# Epoch 45/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.8147 - loss: 0.5000 - val_accuracy: 0.8272 - val_loss: 0.4648
# Epoch 46/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.4201 - val_accuracy: 0.8254 - val_loss: 0.4632
# Epoch 47/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - accuracy: 0.8043 - loss: 0.5074 - val_accuracy: 0.8312 - val_loss: 0.4354
# Epoch 48/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.5004 - val_accuracy: 0.8326 - val_loss: 0.4327
# Epoch 49/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8185 - loss: 0.4965 - val_accuracy: 0.8396 - val_loss: 0.4267
# Epoch 50/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7969 - loss: 0.5152 - val_accuracy: 0.8390 - val_loss: 0.4294
# Epoch 51/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8250 - loss: 0.4755 - val_accuracy: 0.8436 - val_loss: 0.4616
# Epoch 52/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8359 - loss: 0.4695 - val_accuracy: 0.8444 - val_loss: 0.4574
# Epoch 53/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8342 - loss: 0.4589 - val_accuracy: 0.8548 - val_loss: 0.4206
# Epoch 54/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8359 - loss: 0.4110 - val_accuracy: 0.8556 - val_loss: 0.4143
# Epoch 55/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8225 - loss: 0.4746 - val_accuracy: 0.8624 - val_loss: 0.3766
# Epoch 56/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8594 - loss: 0.3816 - val_accuracy: 0.8632 - val_loss: 0.3726
# Epoch 57/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - accuracy: 0.8284 - loss: 0.4574 - val_accuracy: 0.8394 - val_loss: 0.4921
# Epoch 58/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7969 - loss: 0.4806 - val_accuracy: 0.8354 - val_loss: 0.4991
# Epoch 59/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8306 - loss: 0.4557 - val_accuracy: 0.8342 - val_loss: 0.4656
# Epoch 60/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.4607 - val_accuracy: 0.8284 - val_loss: 0.4755
# Epoch 61/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8363 - loss: 0.4389 - val_accuracy: 0.8646 - val_loss: 0.3818
# Epoch 62/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.5025 - val_accuracy: 0.8642 - val_loss: 0.3801
# Epoch 63/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8413 - loss: 0.4334 - val_accuracy: 0.8576 - val_loss: 0.3989
# Epoch 64/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7734 - loss: 0.5628 - val_accuracy: 0.8606 - val_loss: 0.3957
# Epoch 65/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - accuracy: 0.8380 - loss: 0.4336 - val_accuracy: 0.8710 - val_loss: 0.3638
# Epoch 66/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8516 - loss: 0.4077 - val_accuracy: 0.8690 - val_loss: 0.3647
# Epoch 67/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - accuracy: 0.8457 - loss: 0.4122 - val_accuracy: 0.8708 - val_loss: 0.3652
# Epoch 68/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3727 - val_accuracy: 0.8684 - val_loss: 0.3638
# Epoch 69/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.8446 - loss: 0.4206 - val_accuracy: 0.8696 - val_loss: 0.3723
# Epoch 70/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8281 - loss: 0.4399 - val_accuracy: 0.8684 - val_loss: 0.3768
# Epoch 71/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - accuracy: 0.8462 - loss: 0.4086 - val_accuracy: 0.8508 - val_loss: 0.4343
# Epoch 72/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8125 - loss: 0.4746 - val_accuracy: 0.8518 - val_loss: 0.4314
# Epoch 73/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - accuracy: 0.8526 - loss: 0.3991 - val_accuracy: 0.8582 - val_loss: 0.3930
# Epoch 74/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7969 - loss: 0.4783 - val_accuracy: 0.8586 - val_loss: 0.3928
# Epoch 75/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8609 - loss: 0.3845 - val_accuracy: 0.8758 - val_loss: 0.3453
# Epoch 76/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.3790 - val_accuracy: 0.8758 - val_loss: 0.3426
# Epoch 77/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8540 - loss: 0.4033 - val_accuracy: 0.8760 - val_loss: 0.3417
# Epoch 78/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.4077 - val_accuracy: 0.8758 - val_loss: 0.3438
# Epoch 79/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8583 - loss: 0.3914 - val_accuracy: 0.8722 - val_loss: 0.3502
# Epoch 80/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.2553 - val_accuracy: 0.8738 - val_loss: 0.3493
# Epoch 81/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 20s 89ms/step - accuracy: 0.8623 - loss: 0.3765 - val_accuracy: 0.8624 - val_loss: 0.4098
# Epoch 82/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8359 - loss: 0.5503 - val_accuracy: 0.8684 - val_loss: 0.3945
# Epoch 83/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - accuracy: 0.8597 - loss: 0.3792 - val_accuracy: 0.8672 - val_loss: 0.3766
# Epoch 84/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8359 - loss: 0.4905 - val_accuracy: 0.8660 - val_loss: 0.3824
# Epoch 85/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.8653 - loss: 0.3709 - val_accuracy: 0.8758 - val_loss: 0.3701
# Epoch 86/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8516 - loss: 0.4198 - val_accuracy: 0.8742 - val_loss: 0.3718
# Epoch 87/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - accuracy: 0.8695 - loss: 0.3608 - val_accuracy: 0.8686 - val_loss: 0.3773
# Epoch 88/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8438 - loss: 0.3925 - val_accuracy: 0.8708 - val_loss: 0.3721
# Epoch 89/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - accuracy: 0.8657 - loss: 0.3640 - val_accuracy: 0.8820 - val_loss: 0.3388
# Epoch 90/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8906 - loss: 0.3231 - val_accuracy: 0.8804 - val_loss: 0.3380
# Epoch 91/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - accuracy: 0.8635 - loss: 0.3612 - val_accuracy: 0.8826 - val_loss: 0.3212
# Epoch 92/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7812 - loss: 0.5560 - val_accuracy: 0.8834 - val_loss: 0.3201
# Epoch 93/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.8695 - loss: 0.3559 - val_accuracy: 0.8592 - val_loss: 0.4074
# Epoch 94/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.3049 - val_accuracy: 0.8590 - val_loss: 0.4056
# Epoch 95/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8701 - loss: 0.3536 - val_accuracy: 0.8738 - val_loss: 0.3638
# Epoch 96/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8750 - loss: 0.3717 - val_accuracy: 0.8778 - val_loss: 0.3524
# Epoch 97/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 92ms/step - accuracy: 0.8736 - loss: 0.3485 - val_accuracy: 0.8734 - val_loss: 0.3818
# Epoch 98/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8672 - loss: 0.3558 - val_accuracy: 0.8728 - val_loss: 0.3816
# Epoch 99/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.8780 - loss: 0.3368 - val_accuracy: 0.8720 - val_loss: 0.3723
# Epoch 100/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8516 - loss: 0.3906 - val_accuracy: 0.8782 - val_loss: 0.3612

# %%
#model2.save('cifar10_02.h5')         # about 90% accuracy

# %%
#training and test accuracy without dropout
train_acc=model2.evaluate(x_train,y_train,batch_size=128)
train_acc

test_acc=model2.evaluate(x_test,y_test,batch_size=128)
test_acc

print("Training accuracy: ", train_acc[1])
print("Testing accuracy: ", test_acc[1])
# Out:
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9227 - loss: 0.2187
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8782 - loss: 0.3612
# Training accuracy:  0.9227030873298645
# Testing accuracy:  0.8781999945640564

# %%
plothist(history2)  # 128 batch, 0.001 lr,

# %% [markdown]
# # **Plot images**

# %%
# Names of predicted classes (randomly chosen images)

import random


class_names = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# this construction returns the most probable class for each event
y_pred = np.argmax(model2.predict(x_test), axis = 1)
y_pred_prob = model2.predict(x_test)

grid_w = 10
grid_h = 10

fig = plt.figure(figsize=(20, 40))
for i in range(0,grid_w*grid_h):
    i_pos = 2*(int(i/grid_w))*grid_w+ i%grid_w + 1
    plt.subplot(2*grid_h, grid_w, i_pos)
    i_img = random.randint(0,len(xx_test))
    plt.imshow(xx_test[i_img])
    plt.axis('off')
    if yy_test[i_img] == y_pred[i_img]:
      plt.text(0, -2, class_names[int(yy_test[i_img])], color='green', fontsize=12)
    else:
      plt.text(0, -2, class_names[int(yy_test[i_img])]+" "+class_names[y_pred[i_img]], color='red', fontsize=12)
    plt.subplot(2*grid_h, grid_w, i_pos + grid_w)
    plt.bar(range(num_classes),y_pred_prob[i_img])
    plt.axis('off')

plt.show()
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /tmp/ipykernel_673/1004791150.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(0, -2, class_names[int(yy_test[i_img])], color='green', fontsize=12)
# /tmp/ipykernel_673/1004791150.py:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(0, -2, class_names[int(yy_test[i_img])]+" "+class_names[y_pred[i_img]], color='red', fontsize=12)

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model2.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 157/157 - 0s - 3ms/step
# [[887  77  23   6   7]
#  [  3 996   0   1   0]
#  [ 38  31 839  64  28]
#  [ 30  47  47 825  51]
#  [ 19  16  76  45 844]]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # <font color='green'> **Transfer learning**
#
# The reuse of a previously learned model on a new problem is known as transfer learning. It’s particularly popular in deep learning right now since it can train deep neural networks with a small amount of data.
#
# <img src = 'https://editor.analyticsvidhya.com/uploads/444861_2vse-G3FKMT2D59NFWduMA.jpg' width=450px>
#
# The knowledge of an already trained machine learning model is transferred to a different but closely linked problem throughout transfer learning. For example, if you trained a simple classifier to predict whether an image contains a backpack, you could use the model’s training knowledge to identify other objects such as sunglasses.

# %% [markdown]
# # **What is Transfer Learning?**
# With transfer learning, we basically try to use what we’ve learned in one task to better understand the concepts in another. Weights are being automatically being shifted to a network performing “task A” from a network that performed new “task B.”
#
#
# <img src = 'https://editor.analyticsvidhya.com/uploads/751191_rsgubd7aTgUdY65KPYATBA.png' width=450px>
#
# So a network trained to recognize a "cat" can be reused to recognize a "dog".

# %% [markdown]
# <img src = 'https://editor.analyticsvidhya.com/uploads/499849315476_1592890541_transfer.jpg' width=500px>
#
# Because the model has trained to recognise objects in the earlier levels, we will simply retrain the subsequent layers to understand what distinguishes sunglasses from other objects.
#
# **Option is to employ a model that has already been trained. There are a number of these models out there, so do some research beforehand. The number of layers to reuse and retrain is determined by the task.**
#
# Keras consists of many pre-trained models used in transfer learning, prediction, fine-tuning.

# %% [markdown]
# # <font color='green'>**An example – pattern recognition**
# # <font color='green'>**on CIFAR10 photos dataset**
#
# **CIFAR10** small image classification. <br>Dataset of 50\,000 32x32 color training images\, labeled over 10 categories\, and 10\,000 test images\.</span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture7/MachineLearning2020_733.png' width=450px>
#
#
# ###<font color = 'red'> **We have done it already for CIPHAR10, now we reduce the size of dataset even further**

# %% [markdown]
# # Modified version of:
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import keras as k
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from keras.regularizers import l2
import h5py
from keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
# Enable eager execution
tf.config.run_functions_eagerly(True) # This line enables eager execution

# %% [markdown]
# ### **Important:** we reduce the size of the training dataset to 10 000 images.

# %%
 # labels
num_classes=3

#load data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_rows, img_cols , channels = 32,32,3

# REDUCE THE SIZE OF TRAINING SAMPLE TO 10 000 events
x_train = x_train[0:10000]
y_train = y_train[0:10000]

# take some labels only
x_train = x_train[np.where(y_train.reshape(-1)<num_classes)]
y_train = y_train[np.where(y_train.reshape(-1)<num_classes)]
x_test = x_test[np.where(y_test.reshape(-1)<num_classes)]
y_test = y_test[np.where(y_test.reshape(-1)<num_classes)]


# save x_test images
xx_test = x_test
yy_test = y_test

fig = plt.figure(figsize=(8, 8))
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.axis('off')
    plt.imshow(x_train[i])
plt.show()

# %%
#reshape into images
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)
input_shape = (img_rows, img_cols, 1)
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (3011, 32, 32, 3)
# 3011 train samples
# 3000 test samples

# %%
#convert integers to float; normalise and center the mean
x_train=x_train.astype("float32")
x_test=x_test.astype("float32")
mean=np.mean(x_train)
std=np.std(x_train)
x_test=(x_test-mean)/std
x_train=(x_train-mean)/std

# %%
print(y_train.shape)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test  = tf.keras.utils.to_categorical(y_test, num_classes)
print(y_train.shape)
# Out:
# (3011, 1)
# (3011, 3)

# %% [markdown]
# # Data augmentation

# %%
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.25
    )
datagen.fit(x_train)

# %%
# build and compile the model  (roughly following the VGG paper)

#reg=l2(1e-4)   # L2 or "ridge" regularisation
reg=None
num_filters=16 #32
ac='relu'
# Use the standard Adam optimizer from keras.optimizers:
opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

drop_dense=0.5
drop_conv=0

# %% [markdown]
# ## **Regular convolutional network with augmentation**

# %%
model = Sequential()

model.add(Conv2D(num_filters, (3, 3), activation=ac, kernel_regularizer=reg, input_shape=(img_rows, img_cols, channels),padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 16x16x3xnum_filters
model.add(Dropout(drop_conv))

model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(2*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 8x8x3x(2*num_filters)
model.add(Dropout(drop_conv))

model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(Conv2D(4*num_filters, (3, 3), activation=ac,kernel_regularizer=reg,padding='same'))
model.add(BatchNormalization(axis=-1))
model.add(MaxPooling2D(pool_size=(2, 2)))   # reduces to 4x4x3x(4*num_filters)
model.add(Dropout(drop_conv))

model.add(Flatten())
model.add(Dense(512, activation=ac,kernel_regularizer=reg))
model.add(BatchNormalization())
model.add(Dropout(drop_dense))
model.add(Dense(num_classes, activation='softmax'))


model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 32, 32, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │         1,539 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 601,363 (2.29 MB)
#  Trainable params: 599,891 (2.29 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %% [markdown]
# #**Training with augmentation**
#
# Very short training

# %%
# train with image augmentation   steps_per_epoch = len(x_train) / 128,
history=model.fit(datagen.flow(x_train, y_train, batch_size=128),
                     epochs=30, validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 544ms/step - accuracy: 0.5938 - loss: 1.2964 - val_accuracy: 0.3450 - val_loss: 1.1407
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.6546 - loss: 1.0051 - val_accuracy: 0.3373 - val_loss: 1.4541
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 510ms/step - accuracy: 0.7018 - loss: 0.7880 - val_accuracy: 0.3333 - val_loss: 1.6677
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 509ms/step - accuracy: 0.7247 - loss: 0.7222 - val_accuracy: 0.3383 - val_loss: 1.8311
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 546ms/step - accuracy: 0.7386 - loss: 0.6712 - val_accuracy: 0.4503 - val_loss: 2.0049
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.7376 - loss: 0.6636 - val_accuracy: 0.4363 - val_loss: 1.9012
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 514ms/step - accuracy: 0.7605 - loss: 0.5928 - val_accuracy: 0.4730 - val_loss: 2.0661
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 521ms/step - accuracy: 0.7828 - loss: 0.5551 - val_accuracy: 0.4120 - val_loss: 1.8158
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 518ms/step - accuracy: 0.7745 - loss: 0.5300 - val_accuracy: 0.4763 - val_loss: 1.7841
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 515ms/step - accuracy: 0.7811 - loss: 0.5475 - val_accuracy: 0.5953 - val_loss: 1.0581
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 518ms/step - accuracy: 0.7921 - loss: 0.5006 - val_accuracy: 0.6523 - val_loss: 0.8938
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 511ms/step - accuracy: 0.7961 - loss: 0.4962 - val_accuracy: 0.7163 - val_loss: 0.6963
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 547ms/step - accuracy: 0.8080 - loss: 0.4709 - val_accuracy: 0.7943 - val_loss: 0.5121
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 511ms/step - accuracy: 0.8107 - loss: 0.4691 - val_accuracy: 0.7993 - val_loss: 0.4854
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 510ms/step - accuracy: 0.8034 - loss: 0.4776 - val_accuracy: 0.8217 - val_loss: 0.4441
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 508ms/step - accuracy: 0.8120 - loss: 0.4667 - val_accuracy: 0.8373 - val_loss: 0.4252
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 541ms/step - accuracy: 0.8213 - loss: 0.4463 - val_accuracy: 0.8493 - val_loss: 0.3839
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 520ms/step - accuracy: 0.8286 - loss: 0.4428 - val_accuracy: 0.8483 - val_loss: 0.3746
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 519ms/step - accuracy: 0.8313 - loss: 0.4253 - val_accuracy: 0.8450 - val_loss: 0.3970
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.8306 - loss: 0.4241 - val_accuracy: 0.8470 - val_loss: 0.3742
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.8300 - loss: 0.4127 - val_accuracy: 0.8493 - val_loss: 0.3803
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 513ms/step - accuracy: 0.8336 - loss: 0.4234 - val_accuracy: 0.8363 - val_loss: 0.4770
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 518ms/step - accuracy: 0.8336 - loss: 0.4077 - val_accuracy: 0.8523 - val_loss: 0.3634
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.8406 - loss: 0.4056 - val_accuracy: 0.8510 - val_loss: 0.3894
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 512ms/step - accuracy: 0.8333 - loss: 0.3994 - val_accuracy: 0.8503 - val_loss: 0.3736
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 515ms/step - accuracy: 0.8476 - loss: 0.3911 - val_accuracy: 0.8100 - val_loss: 0.5397
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 517ms/step - accuracy: 0.8419 - loss: 0.3877 - val_accuracy: 0.8363 - val_loss: 0.4208
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 516ms/step - accuracy: 0.8456 - loss: 0.3745 - val_accuracy: 0.8030 - val_loss: 0.5429
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 516ms/step - accuracy: 0.8462 - loss: 0.3868 - val_accuracy: 0.7787 - val_loss: 0.6365
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 514ms/step - accuracy: 0.8389 - loss: 0.4011 - val_accuracy: 0.8390 - val_loss: 0.4425

# %%
#training accuracy
train_acc=model.evaluate(x_train,y_train,batch_size=128)
train_acc
test_acc=model.evaluate(x_test,y_test,batch_size=128)
test_acc

print("Training and test accuracies: ", train_acc[1], test_acc[1])
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8675 - loss: 0.3397
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8390 - loss: 0.4425
# Training and test accuracies:  0.8674858808517456 0.8389999866485596

# %%
# plotting helper function
def plothist(hist):
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plothist(history)

# %% [markdown]
# ## **Pretrained network Xception**
#
# The pretrained Xception network is taken from:
#
# https://keras.io/api/applications/
#
# We train the dense layers only!!!

# %%
base_model = k.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(128, 128 , channels),
    include_top=False)  # Do not include the ImageNet classifier at the top.

# Freeze base model
base_model.trainable = False

# Create new model on top.
inputs = k.Input(shape=(32, 32, 3))
# upsampling to get 32x32 -> 128x128
upsamp1 = tf.keras.layers.UpSampling2D((2,2))(inputs)
upsamp2 = tf.keras.layers.UpSampling2D((2,2))(upsamp1)
x = base_model(upsamp2, training=False)

# Dense layers to be trained
x = k.layers.Flatten()(x)
x = k.layers.Dense(128, activation=ac,kernel_regularizer=reg)(x)
x = k.layers.BatchNormalization()(x)
x = k.layers.Dropout(drop_dense)(x)
outputs = k.layers.Dense(num_classes, activation='softmax')(x)

model = k.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "functional_69"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 4, 4, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,056,811 (95.58 MB)
#  Trainable params: 4,195,075 (16.00 MB)
#  Non-trainable params: 20,861,736 (79.58 MB)

# %% [markdown]
# #**Training with augmentation**
#
# Very short training

# %%
# Use the standard Adam optimizer from keras.optimizers:
opt_pre = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=opt_pre)

# %%
#train with image augmentation   steps_per_epoch = len(x_train) / 128,
history=model.fit(datagen.flow(x_train, y_train, batch_size=128),
                     epochs=30, validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.7582 - loss: 0.7667 - val_accuracy: 0.9010 - val_loss: 0.4065
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8107 - loss: 0.4910 - val_accuracy: 0.9063 - val_loss: 0.3276
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8349 - loss: 0.4394 - val_accuracy: 0.9183 - val_loss: 0.2472
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8466 - loss: 0.4053 - val_accuracy: 0.9200 - val_loss: 0.2233
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8592 - loss: 0.3619 - val_accuracy: 0.9200 - val_loss: 0.2336
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.8522 - loss: 0.3985 - val_accuracy: 0.9080 - val_loss: 0.2538
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8635 - loss: 0.3546 - val_accuracy: 0.9237 - val_loss: 0.2166
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8652 - loss: 0.3469 - val_accuracy: 0.9237 - val_loss: 0.2115
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8652 - loss: 0.3527 - val_accuracy: 0.9273 - val_loss: 0.1995
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8725 - loss: 0.3325 - val_accuracy: 0.9290 - val_loss: 0.1993
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8675 - loss: 0.3442 - val_accuracy: 0.9257 - val_loss: 0.2083
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8798 - loss: 0.3249 - val_accuracy: 0.9280 - val_loss: 0.2047
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8794 - loss: 0.3257 - val_accuracy: 0.9267 - val_loss: 0.1948
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8818 - loss: 0.3132 - val_accuracy: 0.9283 - val_loss: 0.1871
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8718 - loss: 0.3215 - val_accuracy: 0.9277 - val_loss: 0.1907
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8881 - loss: 0.3067 - val_accuracy: 0.9280 - val_loss: 0.1945
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8824 - loss: 0.3007 - val_accuracy: 0.9307 - val_loss: 0.1893
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8864 - loss: 0.2813 - val_accuracy: 0.9303 - val_loss: 0.1854
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8984 - loss: 0.2926 - val_accuracy: 0.9333 - val_loss: 0.1813
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.8858 - loss: 0.2906 - val_accuracy: 0.9290 - val_loss: 0.1928
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8894 - loss: 0.2869 - val_accuracy: 0.9310 - val_loss: 0.1925
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8944 - loss: 0.2886 - val_accuracy: 0.9300 - val_loss: 0.1874
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8901 - loss: 0.2856 - val_accuracy: 0.9320 - val_loss: 0.1847
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8911 - loss: 0.2820 - val_accuracy: 0.9260 - val_loss: 0.2034
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8881 - loss: 0.2909 - val_accuracy: 0.9257 - val_loss: 0.2082
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9004 - loss: 0.2648 - val_accuracy: 0.9323 - val_loss: 0.1863
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8970 - loss: 0.2800 - val_accuracy: 0.9377 - val_loss: 0.1794
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8954 - loss: 0.2804 - val_accuracy: 0.9323 - val_loss: 0.1827
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.8917 - loss: 0.2818 - val_accuracy: 0.9347 - val_loss: 0.1851
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.8947 - loss: 0.2793 - val_accuracy: 0.9330 - val_loss: 0.1768

# %%
#training accuracy
train_acc=model.evaluate(x_train,y_train,batch_size=128)
train_acc
test_acc=model.evaluate(x_test,y_test,batch_size=128)
test_acc

print("Training and test accuracies: ", train_acc[1], test_acc[1])
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 225ms/step - accuracy: 0.9535 - loss: 0.1227
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - accuracy: 0.9330 - loss: 0.1768
# Training and test accuracies:  0.9535038471221924 0.9330000281333923

# %%
# plotting helper function
def plothist(hist):
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plothist(history)

# %% [markdown]
# ##<font color = 'red'> **Transfer learning significantly improves our results!**

# %% [markdown]
# #<font color='green'>**Summary**
#
# ##**So\, we know how to recognize what is on images\!**

# %% [markdown]
# #<font color='red'>**Exercise**
#
# * <mark> Build your own convolutional neural network to recognize elements from the "Fashion MNIST" dataset: https://keras.io/api/datasets/fashion_mnist/
# * <mark> Implement **augmentation** in this code or **transfer learning**.
# * A volunteer can present his code.

# %% [markdown]
# # **Think about your classification tasks!!!**
#
# Might be a piece of your current analysis!

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# <center>
#
# # <font color='green'> **Cross-validation - using all data for training**

# %% [markdown]
# <span style="color:#000000"> __Overtraining__ </span>  <span style="color:#000000"> – algorithm “learns” the particular events\, not the rules\.</span>
#
# <span style="color:#800000"> _This effect appears for all ML algorithms\._ </span>
#
# <span style="color:#000000">Remedy – checking with another\, independent dataset\.</span>

# %% [markdown]
# <span style="color:#800000"> __How to train a ML algorithm?__ </span>
#
# * <span style="color:#000000">How to avoid </span>  <span style="color:#000000"> __overtraining__ </span>  <span style="color:#000000"> while learning?</span>
#
# * <span style="color:#000000">We should use one sample for </span>  <span style="color:#000000"> __training__ </span>  <span style="color:#000000"> and another for </span>  <span style="color:#000000"> __validating__ </span>
#
# * <span style="color:#000000">Then we increase the error – we use just a part of data for training\.</span>
#
# <span style="color:#C9211E"> __Important remark:__ </span>  <span style="color:#000000"> to avoid ovetraining and find the performance of the trained algorithm we should use one more\, </span>  <span style="color:#C9211E"> __third data sample__ </span>  <span style="color:#000000"> to measure the final performance of the ML algorithm\.</span>
#
#
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_85.png' width=450px>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #<span style="color:#800000"> __Cross\-validation__ </span>
#
# <span style="color:#000000">We have independant training sample $L_n$ and a test sample $T_m$. </span>
#
# <span style="color:#000000">Error level of the classifier                          built on the training sample $L_n$:
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_818.png' width=200px>
#
# **"Standard" procedure:**
#
# * <span style="color:#000000">Estimator using "recycled data" \(the same data for training and for error calculation\) is biased\.</span>
#
# * <span style="color:#000000">Reduction of bias: division of data into two parts \(training & validation\)\. But than we use just a half of information only\.</span>
#
# **Cross\-validation:**
#
# – out of sample $L_n$ we remove just one event $j$, than train classifier\, validate on single event $j$\.
#
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_819.png' width=250px>
#
# We repeat $n$ times and get the estimator \(an average of all n estimators\): </span>
#
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_820.png' width=250px>
#
# <span style="color:#000000">We get an estimator\, which is unbiased \(in the limit of huge $n$\)\,**but training is CPU demanding**\. </span>

# %% [markdown]
# #**Cross\-validation**
#
# <span style="color:#000000">Intermediate solution –</span>   <span style="color:#000000"> **_k\-fold cross\-validation_** </span>
#
# <span style="color:#000000">The sample is divided into $k$ subsamples\, $k-1$ of them we use for training\, the one for validation\. Then the procedure is repeated with other subsamples and the procedure is repeated k times\. </span>
#
# <span style="color:#000000">Smaller CPU usage comparing to the full cross\-validation\.</span>
#
# <span style="color:#000000">Recommended $k \approx 10$ \.</span>
#
# <span style="color:#000000">Resulting classifier might be in the simplest case an average of all k classifiers \(or they might be joined together in another way\) \.</span>

# %% [markdown]
# #<span style="color:#800000"> __Model performance__ </span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_824.png' width=650px>
#
#
#
# #__Train vs Test vs Valid__ </span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_825.png' width=650px>
#
#
# Source: <span style="color:#000000">[https://www\.slideshare\.net/0xdata/top\-10\-data\-science\-practitioner\-pitfalls](https://www.slideshare.net/0xdata/top-10-data-science-practitioner-pitfalls)</span>

# %% [markdown]
# # **Cross-validation example**
# # **Hand-written digits classification with k-folding**

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from tensorflow.keras.optimizers import RMSprop, Adam, Adadelta
from keras.callbacks import EarlyStopping

#from keras.utils import plot_model
from IPython.display import Image

from sklearn.model_selection import KFold

batch_size = 128
num_classes = 10
epochs = 20

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # **Reduce the dataset size**
#
# so we see the performance deterioration.

# %%
N_TRAIN_EXAMPLES = 30000 #9000
N_TEST_EXAMPLES = 10000

x_train = x_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# %%
#visualize the digits

fig = plt.figure(figsize=(10, 10))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(100):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(y_train0[i]))

# %%
def define_model():
# Our old fully connected (dense) network
#model = Sequential()
#model.add(Dense(512, activation='relu', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(num_classes, activation='softmax'))

  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes, activation='softmax'))



  #model.summary()

  return model

# %%
def plotModel(model):
  plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
  Image('model_plot.png')

# %% [markdown]
# ### Here we introduce "early stopping"

# %%
def fit_model(model, x_train, y_train, x_val, y_val):
  model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

  es = EarlyStopping(
    monitor="val_loss",
    patience=3,
    verbose=0
  )

  history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_val, y_val),
                    callbacks=[es])
  return history, model

# %% [markdown]
# # **Train with k-folding**
# **Here the KFold() function from scikit-learn is used**

# %%
# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):

  # prepare cross validation
  kfold = KFold(n_folds, shuffle=True, random_state=1)
  # enumerate splits
  for train_ix, test_ix in kfold.split(dataX):
    # define model
    model = define_model()
    # select rows for train and test
    trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
    # fit model
    history, model = fit_model(model, trainX, trainY, testX, testY)
    # evaluate model
    _, acc = model.evaluate(testX, testY, verbose=0)
    print('> %.3f' % (acc * 100.0))
		# stores scores
    scores.append(acc)
    histories.append(history)
    models.append(model)
  return scores, histories, models

# %% [markdown]
# # **Make plots**

# %%
# plot diagnostic learning curves
def summarize_diagnostics(histories):
  plt.figure(figsize=(10,10))
  for i in range(len(histories)):
		# plot loss
    plt.subplot(2, 1, 1)
    plt.title('Loss')
    plt.plot(histories[i].history['loss'], color='blue', label='train')
    plt.plot(histories[i].history['val_loss'], color='orange', label='test')
    plt.ylim(0,0.1)
    plt.legend(['loss','val_loss'])
    # plot accuracy
    plt.subplot(2, 1, 2)
    plt.title('Classification Accuracy')
    plt.plot(histories[i].history['accuracy'], color='blue', label='train')
    plt.plot(histories[i].history['val_accuracy'], color='orange', label='test')
    plt.ylim(0.9,1)
    plt.legend(['accuracy','val_accuracy'])
  plt.show()

# summarize model performance
def summarize_performance(scores):
	# print summary
  print('Accuracy: mean=%.3f std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
	# box and whisker plots of results
  plt.figure(figsize=(10,10))
  plt.boxplot(scores)
  plt.show()

# %% [markdown]
# # **Perform training**

# %%
	scores, histories, models = list(), list(), list()

  # evaluate model
	scores, histories, models = evaluate_model(x_train, y_train, n_folds=10)
# Out:
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 110ms/step - accuracy: 0.8456 - loss: 0.4807 - val_accuracy: 0.9700 - val_loss: 0.0964
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9586 - loss: 0.1350 - val_accuracy: 0.9807 - val_loss: 0.0583
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9721 - loss: 0.0962 - val_accuracy: 0.9853 - val_loss: 0.0437
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9780 - loss: 0.0728 - val_accuracy: 0.9893 - val_loss: 0.0295
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9805 - loss: 0.0629 - val_accuracy: 0.9883 - val_loss: 0.0369
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9844 - loss: 0.0528 - val_accuracy: 0.9883 - val_loss: 0.0296
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9863 - loss: 0.0458 - val_accuracy: 0.9913 - val_loss: 0.0287
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9864 - loss: 0.0441 - val_accuracy: 0.9890 - val_loss: 0.0343
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 110ms/step - accuracy: 0.9871 - loss: 0.0425 - val_accuracy: 0.9877 - val_loss: 0.0370
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9892 - loss: 0.0346 - val_accuracy: 0.9930 - val_loss: 0.0257
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9898 - loss: 0.0330 - val_accuracy: 0.9897 - val_loss: 0.0299
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9903 - loss: 0.0305 - val_accuracy: 0.9897 - val_loss: 0.0285
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9907 - loss: 0.0289 - val_accuracy: 0.9910 - val_loss: 0.0251
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9917 - loss: 0.0266 - val_accuracy: 0.9927 - val_loss: 0.0299
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9909 - loss: 0.0275 - val_accuracy: 0.9913 - val_loss: 0.0265
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9923 - loss: 0.0231 - val_accuracy: 0.9927 - val_loss: 0.0270
# > 99.267
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.8448 - loss: 0.4852 - val_accuracy: 0.9750 - val_loss: 0.0837
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9584 - loss: 0.1353 - val_accuracy: 0.9857 - val_loss: 0.0493
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9707 - loss: 0.0969 - val_accuracy: 0.9893 - val_loss: 0.0352
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9774 - loss: 0.0749 - val_accuracy: 0.9923 - val_loss: 0.0277
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9820 - loss: 0.0619 - val_accuracy: 0.9913 - val_loss: 0.0290
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9844 - loss: 0.0496 - val_accuracy: 0.9913 - val_loss: 0.0280
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9859 - loss: 0.0456 - val_accuracy: 0.9940 - val_loss: 0.0235
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9866 - loss: 0.0435 - val_accuracy: 0.9937 - val_loss: 0.0236
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9885 - loss: 0.0397 - val_accuracy: 0.9930 - val_loss: 0.0269
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9885 - loss: 0.0352 - val_accuracy: 0.9937 - val_loss: 0.0214
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9906 - loss: 0.0309 - val_accuracy: 0.9910 - val_loss: 0.0270
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9900 - loss: 0.0303 - val_accuracy: 0.9937 - val_loss: 0.0222
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9910 - loss: 0.0297 - val_accuracy: 0.9937 - val_loss: 0.0244
# > 99.367
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.8426 - loss: 0.4814 - val_accuracy: 0.9680 - val_loss: 0.1074
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9597 - loss: 0.1334 - val_accuracy: 0.9820 - val_loss: 0.0681
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9722 - loss: 0.0917 - val_accuracy: 0.9833 - val_loss: 0.0556
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9774 - loss: 0.0743 - val_accuracy: 0.9857 - val_loss: 0.0500
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9821 - loss: 0.0606 - val_accuracy: 0.9883 - val_loss: 0.0442
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9845 - loss: 0.0518 - val_accuracy: 0.9877 - val_loss: 0.0487
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9856 - loss: 0.0458 - val_accuracy: 0.9900 - val_loss: 0.0398
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9876 - loss: 0.0409 - val_accuracy: 0.9897 - val_loss: 0.0415
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9874 - loss: 0.0380 - val_accuracy: 0.9893 - val_loss: 0.0422
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9894 - loss: 0.0339 - val_accuracy: 0.9903 - val_loss: 0.0344
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9897 - loss: 0.0315 - val_accuracy: 0.9910 - val_loss: 0.0392
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9919 - loss: 0.0263 - val_accuracy: 0.9900 - val_loss: 0.0377
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9910 - loss: 0.0296 - val_accuracy: 0.9907 - val_loss: 0.0370
# > 99.067
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.8455 - loss: 0.4825 - val_accuracy: 0.9703 - val_loss: 0.0953
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9580 - loss: 0.1422 - val_accuracy: 0.9810 - val_loss: 0.0592
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9679 - loss: 0.1051 - val_accuracy: 0.9843 - val_loss: 0.0560
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9761 - loss: 0.0789 - val_accuracy: 0.9893 - val_loss: 0.0451
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9814 - loss: 0.0626 - val_accuracy: 0.9877 - val_loss: 0.0456
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9824 - loss: 0.0576 - val_accuracy: 0.9907 - val_loss: 0.0370
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9857 - loss: 0.0451 - val_accuracy: 0.9897 - val_loss: 0.0427
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9874 - loss: 0.0415 - val_accuracy: 0.9913 - val_loss: 0.0324
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9867 - loss: 0.0409 - val_accuracy: 0.9913 - val_loss: 0.0367
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9885 - loss: 0.0367 - val_accuracy: 0.9927 - val_loss: 0.0337
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9888 - loss: 0.0353 - val_accuracy: 0.9910 - val_loss: 0.0429
# > 99.100
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.8416 - loss: 0.4900 - val_accuracy: 0.9737 - val_loss: 0.0828
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9609 - loss: 0.1270 - val_accuracy: 0.9847 - val_loss: 0.0510
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9715 - loss: 0.0914 - val_accuracy: 0.9900 - val_loss: 0.0323
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9783 - loss: 0.0714 - val_accuracy: 0.9907 - val_loss: 0.0322
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9823 - loss: 0.0590 - val_accuracy: 0.9913 - val_loss: 0.0289
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 42s 109ms/step - accuracy: 0.9844 - loss: 0.0506 - val_accuracy: 0.9920 - val_loss: 0.0276
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9854 - loss: 0.0474 - val_accuracy: 0.9927 - val_loss: 0.0254
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9876 - loss: 0.0382 - val_accuracy: 0.9923 - val_loss: 0.0287
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 108ms/step - accuracy: 0.9889 - loss: 0.0353 - val_accuracy: 0.9913 - val_loss: 0.0258
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9900 - loss: 0.0328 - val_accuracy: 0.9930 - val_loss: 0.0196
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9899 - loss: 0.0318 - val_accuracy: 0.9933 - val_loss: 0.0234
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9903 - loss: 0.0300 - val_accuracy: 0.9947 - val_loss: 0.0230
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9908 - loss: 0.0290 - val_accuracy: 0.9943 - val_loss: 0.0209
# > 99.433
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.8427 - loss: 0.4820 - val_accuracy: 0.9723 - val_loss: 0.0885
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.9603 - loss: 0.1293 - val_accuracy: 0.9823 - val_loss: 0.0582
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.9726 - loss: 0.0923 - val_accuracy: 0.9873 - val_loss: 0.0478
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 113ms/step - accuracy: 0.9775 - loss: 0.0753 - val_accuracy: 0.9903 - val_loss: 0.0354
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.9820 - loss: 0.0617 - val_accuracy: 0.9903 - val_loss: 0.0304
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9836 - loss: 0.0530 - val_accuracy: 0.9913 - val_loss: 0.0294
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9851 - loss: 0.0474 - val_accuracy: 0.9897 - val_loss: 0.0313
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9853 - loss: 0.0466 - val_accuracy: 0.9880 - val_loss: 0.0389
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9885 - loss: 0.0363 - val_accuracy: 0.9937 - val_loss: 0.0243
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9895 - loss: 0.0326 - val_accuracy: 0.9933 - val_loss: 0.0279
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9908 - loss: 0.0295 - val_accuracy: 0.9937 - val_loss: 0.0240
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9902 - loss: 0.0310 - val_accuracy: 0.9917 - val_loss: 0.0259
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9910 - loss: 0.0292 - val_accuracy: 0.9933 - val_loss: 0.0272
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9910 - loss: 0.0266 - val_accuracy: 0.9940 - val_loss: 0.0229
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9919 - loss: 0.0237 - val_accuracy: 0.9923 - val_loss: 0.0242
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9920 - loss: 0.0239 - val_accuracy: 0.9937 - val_loss: 0.0247
# Epoch 17/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9927 - loss: 0.0211 - val_accuracy: 0.9947 - val_loss: 0.0224
# Epoch 18/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9935 - loss: 0.0220 - val_accuracy: 0.9913 - val_loss: 0.0222
# Epoch 19/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9938 - loss: 0.0190 - val_accuracy: 0.9937 - val_loss: 0.0258
# Epoch 20/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9941 - loss: 0.0199 - val_accuracy: 0.9947 - val_loss: 0.0211
# > 99.467
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.8352 - loss: 0.5057 - val_accuracy: 0.9727 - val_loss: 0.0951
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9588 - loss: 0.1338 - val_accuracy: 0.9793 - val_loss: 0.0709
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.9716 - loss: 0.0971 - val_accuracy: 0.9867 - val_loss: 0.0496
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.9783 - loss: 0.0727 - val_accuracy: 0.9880 - val_loss: 0.0391
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9814 - loss: 0.0628 - val_accuracy: 0.9873 - val_loss: 0.0450
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9845 - loss: 0.0534 - val_accuracy: 0.9903 - val_loss: 0.0359
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9860 - loss: 0.0458 - val_accuracy: 0.9897 - val_loss: 0.0359
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9870 - loss: 0.0413 - val_accuracy: 0.9910 - val_loss: 0.0310
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9885 - loss: 0.0385 - val_accuracy: 0.9923 - val_loss: 0.0277
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9888 - loss: 0.0357 - val_accuracy: 0.9927 - val_loss: 0.0303
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9900 - loss: 0.0311 - val_accuracy: 0.9920 - val_loss: 0.0314
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9906 - loss: 0.0290 - val_accuracy: 0.9917 - val_loss: 0.0333
# > 99.167
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.8359 - loss: 0.5025 - val_accuracy: 0.9713 - val_loss: 0.0988
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.9580 - loss: 0.1360 - val_accuracy: 0.9797 - val_loss: 0.0656
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9730 - loss: 0.0958 - val_accuracy: 0.9840 - val_loss: 0.0464
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 110ms/step - accuracy: 0.9776 - loss: 0.0759 - val_accuracy: 0.9837 - val_loss: 0.0511
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9808 - loss: 0.0622 - val_accuracy: 0.9877 - val_loss: 0.0362
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9845 - loss: 0.0489 - val_accuracy: 0.9903 - val_loss: 0.0361
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9859 - loss: 0.0473 - val_accuracy: 0.9897 - val_loss: 0.0310
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9869 - loss: 0.0402 - val_accuracy: 0.9890 - val_loss: 0.0373
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9887 - loss: 0.0363 - val_accuracy: 0.9897 - val_loss: 0.0367
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - accuracy: 0.9894 - loss: 0.0339 - val_accuracy: 0.9913 - val_loss: 0.0276
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9902 - loss: 0.0315 - val_accuracy: 0.9917 - val_loss: 0.0279
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9910 - loss: 0.0285 - val_accuracy: 0.9920 - val_loss: 0.0257
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9911 - loss: 0.0276 - val_accuracy: 0.9907 - val_loss: 0.0284
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9922 - loss: 0.0248 - val_accuracy: 0.9910 - val_loss: 0.0316
# Epoch 15/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9924 - loss: 0.0235 - val_accuracy: 0.9937 - val_loss: 0.0229
# Epoch 16/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.9907 - val_loss: 0.0279
# Epoch 17/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9929 - loss: 0.0210 - val_accuracy: 0.9907 - val_loss: 0.0304
# Epoch 18/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9947 - loss: 0.0164 - val_accuracy: 0.9900 - val_loss: 0.0357
# > 99.000
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.8415 - loss: 0.4805 - val_accuracy: 0.9720 - val_loss: 0.0954
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9590 - loss: 0.1353 - val_accuracy: 0.9817 - val_loss: 0.0628
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9726 - loss: 0.0907 - val_accuracy: 0.9877 - val_loss: 0.0469
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.9774 - loss: 0.0746 - val_accuracy: 0.9860 - val_loss: 0.0477
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9821 - loss: 0.0602 - val_accuracy: 0.9880 - val_loss: 0.0398
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.9834 - loss: 0.0549 - val_accuracy: 0.9890 - val_loss: 0.0398
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 110ms/step - accuracy: 0.9854 - loss: 0.0493 - val_accuracy: 0.9907 - val_loss: 0.0374
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9869 - loss: 0.0437 - val_accuracy: 0.9907 - val_loss: 0.0335
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9883 - loss: 0.0376 - val_accuracy: 0.9897 - val_loss: 0.0364
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9875 - loss: 0.0384 - val_accuracy: 0.9913 - val_loss: 0.0316
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.9898 - loss: 0.0327 - val_accuracy: 0.9917 - val_loss: 0.0309
# Epoch 12/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9913 - loss: 0.0273 - val_accuracy: 0.9930 - val_loss: 0.0323
# Epoch 13/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9913 - loss: 0.0249 - val_accuracy: 0.9907 - val_loss: 0.0429
# Epoch 14/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9924 - loss: 0.0233 - val_accuracy: 0.9933 - val_loss: 0.0374
# > 99.333
# Epoch 1/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.8353 - loss: 0.5009 - val_accuracy: 0.9723 - val_loss: 0.0930
# Epoch 2/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 113ms/step - accuracy: 0.9607 - loss: 0.1336 - val_accuracy: 0.9763 - val_loss: 0.0754
# Epoch 3/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9724 - loss: 0.0901 - val_accuracy: 0.9850 - val_loss: 0.0532
# Epoch 4/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 112ms/step - accuracy: 0.9788 - loss: 0.0716 - val_accuracy: 0.9853 - val_loss: 0.0444
# Epoch 5/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 111ms/step - accuracy: 0.9829 - loss: 0.0599 - val_accuracy: 0.9847 - val_loss: 0.0426
# Epoch 6/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.9836 - loss: 0.0508 - val_accuracy: 0.9893 - val_loss: 0.0340
# Epoch 7/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 110ms/step - accuracy: 0.9861 - loss: 0.0438 - val_accuracy: 0.9877 - val_loss: 0.0371
# Epoch 8/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 41s 111ms/step - accuracy: 0.9874 - loss: 0.0413 - val_accuracy: 0.9877 - val_loss: 0.0382
# Epoch 9/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 24s 111ms/step - accuracy: 0.9885 - loss: 0.0363 - val_accuracy: 0.9900 - val_loss: 0.0334
# Epoch 10/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - accuracy: 0.9906 - loss: 0.0303 - val_accuracy: 0.9907 - val_loss: 0.0357
# Epoch 11/20
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 23s 108ms/step - accuracy: 0.9909 - loss: 0.0293 - val_accuracy: 0.9903 - val_loss: 0.0325
# Epoch 12/20
#  69/211 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.9873 - loss: 0.0395

# %% [markdown]
# # **Summarize**

# %%
# learning curves
summarize_diagnostics(histories)
# summarize estimated performance
summarize_performance(scores)

print("Scores: ",scores)

# %% [markdown]
# # **Ensamble of networks**

# %%
results = np.zeros(y_test.shape)
for j in range(len(models)):
    results = results + models[j].predict(x_test)

results = results / len(models)
results = np.argmax(results,axis = 1)
Yresults = np.argmax(y_test,axis = 1)

#print(results.shape)


score = (len(results) - np.count_nonzero(results-Yresults))/len(results)

print("Ensamble test accuracy: ",score*100.,"%")

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix


#confusion matrix
cm = confusion_matrix(Yresults,results)
print(cm)

# %%
# use the model to predict the labels of the test data
predicted = results
expected = Yresults

#print(predicted.shape, expected.shape)

# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if predicted[i] == expected[i]:
         ax.text(0,7,str(expected[i])+" "+str(predicted[i]), color='green')
    else:
         ax.text(0,7,str(expected[i])+" "+str(predicted[i]), color='red')

# %% [markdown]
# #<font color='red'>**Exercise**
#
# * <mark> Build your own convolutional neural network to recognize elements from the "Fashion MNIST" dataset: https://keras.io/api/datasets/fashion_mnist/
# * <mark>Implement **augmentation** in this code or **transfer learning** or **cross-validation**.
# * A volunteer can present his code.

# %% [markdown]
# ---
#
# ---
#
# ---
#
# <center>
#
# #<font color='green'>**Hyperparameter optimization**
#
# </center>
#
# <span style="color:#C9211E">How to </span>  <span style="color:#C9211E"> __optimize the hyperparameters__ </span>  <span style="color:#C9211E"> of the ML algorithm \(number of trees and their depth for BDT\, number of hidden layers\, nodes for Neural Network\)?</span>
#
# * <span style="color:#000000">Nearly each ML method has few hyperparameters \(structure of the Neural Net\, number of trees and their depth for BDT etc\)\.</span>
# * <span style="color:#000000">They should be optimized for a given problem\.</span>
# * <span style="color:#800000"> __Task: for a given data sample find a set of hyperparameters\, that the estimated error of the given method is minimized\.__ </span>
# * <span style="color:#000000">Looks like a typical minimization problem \(fitting like\)\, but:</span>
#   * <span style="color:#000000">Getting each measurement is costly</span>
#   * <span style="color:#000000">High noise</span>
#   * <span style="color:#000000">We can get the value of the minimized function \(so our error\) in the pont </span>  <span style="color:#000000"> __x__ </span>  <span style="color:#000000"> of the hyperparameter space\,  but we can't get the differential easily\.</span>

# %% [markdown]
# # **How does it work in practice? Bayesian approach**
#
# <span style="color:#000000">Straight line fitting:</span>
#
# $$y(x, w) = w_0+ w_1 x$$
#
# * <span style="color:#000000">Gaussian prior\, no data used</span>
#
# * <span style="color:#000000">First data point\. We find the likelihood based on this point \(left plot\) and multiply: $prior*likelihood$. We get the posterior distribution \(right plot\)\.</span>
#
# * <span style="color:#000000">We add the second point and repeat the procedure\.</span>
#
# * <span style="color:#000000">Adding all the points one by one\.</span>
#
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_86.png' width=450px>
#
#
# ---

# %% [markdown]
# #<font color='green'>**Optimization of hyperparameters**
#
# * <span style="color:#000000">How to optimize:</span>
#   * <span style="color:#000000">**"Grid search”** \- scan over all possible values of parameters\. </span>
#   * **"Random search”**
#   * <span style="color:#000000">Some type of fitting…</span>
# * <span style="color:#000000">Popular method of fitting is the </span>  <span style="color:#000000"> __"bayesian optimization”:__ </span>
#   * <span style="color:#000000">Build the probability model</span>
#   * <span style="color:#000000">Take „a priori” distributions of parameters</span>
#   * <span style="color:#000000">Find\, for which point in the hyperparameter space you can maximally improve your model</span>
#   * <span style="color:#000000">Find the value of error</span>
#   * <span style="color:#000000">Find the „a posteriori” probability distribution</span>
#   * <span style="color:#000000">Repeat</span>

# %% [markdown]
# #<font color='green'> **Bayesian optimization**

# %% [markdown]
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_87.png' width=450px>
#
# <span style="color:#CE181E"> __We are searching for a MAXIMUM__ </span>
#
# Unknown function \(with noise\)\, four observations\.
#
# Where should we do the next costly probing?
#
# *Plots from:
# [https://www\.iro\.umontreal\.ca/~bengioy/cifar/NCAP2014\-summerschool/slides/Ryan\_adams\_140814\_bayesopt\_ncap\.pdf](https://www.iro.umontreal.ca/~bengioy/cifar/NCAP2014-summerschool/slides/Ryan_adams_140814_bayesopt_ncap.pdf)*

# %% [markdown]
# <span style="color:#800000"> __A posteriori distribution__ </span>
#
# A set of functions
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_88.png' width=450px>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_89.png' width=450px>
#
# The a posteriori distribution of possible functions\, those functions could generate the observed data points\.

# %% [markdown]
# <span style="color:#800000"> __A posteriori functions  – Gaussian Processes \(GP\)__ </span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_810.png' width=450px>
#
# These functions should be somehow parametrized\, for example they could be Gaussian functions\.
#
# <span style="color:#800000"> __Acquisition function__ </span>
#
# * <span style="color:#000000">Posterior GP \(Gaussian Processes\) give us the mean of GP functions </span>  <span style="color:#000000">μ</span>  <span style="color:#000000">\(x\) and their expected variation</span>  <span style="color:#000000"> </span>  $\sigma^2(x)$.</span>
#   * <span style="color:#000000"> __Exploration__ </span>  <span style="color:#000000"> – searching for huge variation</span>
#   * <span style="color:#000000"> __Exploitation__ </span>  <span style="color:#000000"> – searching for a smallest/greatest \(depends on sign and convention\) value of mean  </span>  <span style="color:#000000">μ</span>  <span style="color:#000000">\(x\)</span>
# * <span style="color:#000000">The acquisition policy has to balance these two approaches</span>
#
# <span style="color:#800000"> __Where to put the next point?__ </span>
#
# <span style="color:#000000">Our next chosen point\( x \) should has high mean \(exploitation\) & high variance \(exploration\)\.</span>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_811.png' width=450px>
#
# <span style="color:#800000"> __We choose next x__ </span>
#
# u\(x\) – acqusition function \(finding maximum\)
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_812.png' width=450px>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_813.png' width=450px>
#
# We probe once more and repeat the procedure\.\.\.
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_814.png' width=450px>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_815.png' width=450px>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_816.png' width=450px>
#
# <img src='https://raw.githubusercontent.com/marcinwolter/Machine-learning-KISD-2022/main/images/lecture8/MachineLearning2020_817.png' width=450px>

# %% [markdown]
# * <span style="color:#000000">Bayesian optimization depends on the parameters chosen</span>
# * <span style="color:#000000">On the acquisition function</span>
# * <span style="color:#000000">On the prior selected\.\.\.\.</span>
# * <span style="color:#000000">It’s </span>  <span style="color:#000000"> __sequential\.__ </span>
#
# ---

# %% [markdown]
# #<font color='green'>**Implementations of hyperparameter tuning**
#
#   * <span style="color:#000000">Tree of Parzen Estimators \(TPE\) used by the HyperOpt package </span>  <span style="color:#B84700">[https://github\.com/hyperopt/hyperopt](https://github.com/hyperopt/hyperopt)</span>  <span style="color:#000000">\)\.</span>
#   * <span style="color:#000000">OPTUNA package [https://optuna\.org/](https://optuna.org/) Quite advanced\, grid search\, random sampling\,TPE and Covariance Matrix Adaptation Evolution Strategy CMA\-ES algorithms</span>
#   * keras tuner *https://www.tensorflow.org/tutorials/keras/keras_tuner* (RandomSearch,
# BayesianOptimization,
# Hyperband,
# Sklearn Tuner)
#   * <span style="color:#000000">Many more packages\.\.\.</span>
#
# ---
#
# __Nice OPTUNA vs\. HYPEROPT comparison:__
#
# __[https://neptune\.ai/blog/optuna\-vs\-hyperopt](https://neptune.ai/blog/optuna-vs-hyperopt)__

# %% [markdown]
# # **<span style="color:#000000">Simple example with HYPEROPT**

# %%
#Hyperopt demo - minimize x^2 function

from hyperopt import fmin, tpe, rand, hp, STATUS_OK, Trials, plotting
import matplotlib.pyplot as plt

fspace = {
    'x': hp.uniform('x', -5, 5)
}

def f(params):
    x = params['x']
    val = x**2
    return {'loss': val, 'status': STATUS_OK}

trials = Trials()

# possible algos: algo= (tpe.suggest, rand.suggest, )
best = fmin(fn=f, space=fspace, algo=tpe.suggest,  max_evals=1000, trials=trials)
print('best:', best)
print(' trials:')

#for trial in trials.trials[:2]:
#    print(trial)

# %%
#print(trials.trials)

# %%
plotting.main_plot_history(trials)

# %%
plotting.main_plot_histogram(trials)

# %%
plotting.main_plot_vars(trials)

# %%
f, ax = plt.subplots(1)

xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['x'] for t in trials.trials]

ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$x$ $vs$ $t$ ', fontsize=18)
ax.set_xlabel('$t$', fontsize=16)
ax.set_ylabel('$x$', fontsize=16)

# %%
f, ax = plt.subplots(1)

xs = [t['misc']['vals']['x'] for t in trials.trials]
ys = [t['result']['loss'] for t in trials.trials]

ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$val$ $vs$ $x$ ', fontsize=18)
ax.set_xlabel('$x$', fontsize=16)
ax.set_ylabel('$val$', fontsize=16)

# %% [markdown]
# # **Optuna demo**

# %%
# install optuna
! pip install optuna

# %%
import optuna

def objective(trial):
    x = trial.suggest_uniform('x', -10, 10)
    y = trial.suggest_uniform('y', -10, 10)

    return (x - 2) ** 2 + (y-1) ** 2


study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(), sampler=optuna.samplers.TPESampler() )

study.optimize(objective, n_trials=200)

study.best_params  # E.g. {'x': 2.0912375440412942, 'y': 1.0091490823506173}

# %% [markdown]
# ## Visualizing the Optimization History

# %%
from optuna.visualization import plot_optimization_history

plot_optimization_history(study)

# %% [markdown]
# ## Visualizing High-dimensional Parameter Relationships

# %%
from optuna.visualization import plot_parallel_coordinate

plot_parallel_coordinate(study, params=['x', 'y'])

# %% [markdown]
# ## Visualizing Parameter Relationships

# %%
from optuna.visualization import plot_contour

plot_contour(study)

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_contour(study, params=['x', 'y'])

# %% [markdown]
# ## Visualizing Individual Parameters

# %%
from optuna.visualization import plot_slice

plot_slice(study)

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_slice(study, params=['x', 'y'])

# %% [markdown]
# ## Visualizing Parameter Importances

# %%
from optuna.visualization import plot_param_importances

plot_param_importances(study)

# %% [markdown]
# #<font color='green'>**Examples of optimalization of hand written digits classification using hyperopt, optuna and keras tuner**

# %% [markdown]
# #<font color='red'>**MNIST hyperopt optimalization**

# %%
'''Trains a simple deep NN on the MNIST dataset.


'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

batch_size = 128
num_classes = 10
epochs = 20

N_TRAIN_EXAMPLES = 3000
N_TEST_EXAMPLES = 1000

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()


x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# print info about a shape of arrays
print(x_train.shape, 'train samples')
print(x_test.shape, 'test samples')
print(y_train.shape, 'train samples')
print(y_test.shape, 'test samples')

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test  = tf.keras.utils.to_categorical(y_test, num_classes)


# take a subset of all MNIST events
x_train = x_train[:N_TRAIN_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# print info about a shape of arrays
print(x_train.shape, 'train samples after conversion')
print(x_test.shape, 'test samples  after conversion')
print(y_train.shape, 'train samples after conversion')
print(y_test.shape, 'test samples  after conversion')

# %%
space = {

            'units1': hp.quniform('units1', 32,3*1024,32),
            'dropout1': hp.uniform('dropout1', .00,.50),

        }

# %%
def f_nn(params):

    #print ('Parameters testing: ', params)

    model = Sequential()
    model.add(Dense(int(params['units1']), activation='relu', input_shape=(784,)))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(int(params['units1']), activation='relu'))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(int(params['units1']), activation='relu'))
    model.add(Dropout(params['dropout1']))
    model.add(Dense(num_classes, activation='softmax'))

    #model.summary()

    model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

    history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=0,
                    validation_data=(x_test, y_test))

    score = model.evaluate(x_test, y_test, verbose=0)
    #print('Test accuracy:', score[1])
    # return 'accuracy'
    return {'loss': -score[1], 'status': STATUS_OK}

# %% [markdown]
# # **Find the best parameters:**

# %%
trials = Trials()
best = fmin(fn=f_nn, space=space, algo=tpe.suggest, max_evals=50, trials=trials)

# %%
print('best: ', best)
print('best accuracy: ',-trials.best_trial['result']['loss'])

#from hyperopt import space_eval
#print('best parameters: ',space_eval(space, best))

# %% [markdown]
# # **Visualization**

# %%
print(trials.trials)

# %%
from hyperopt import plotting

plotting.main_plot_history(trials)

# %%
plotting.main_plot_histogram(trials)

# %%
plotting.main_plot_vars(trials)

# %%
#units vs time

f, ax = plt.subplots(1)
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['units1'] for t in trials.trials]
ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$units$ $vs$ $time$ ', fontsize=18)
ax.set_xlabel('$time$', fontsize=16)
ax.set_ylabel('$units$', fontsize=16)

# %%
#units vs time

f, ax = plt.subplots(1)
xs = [t['tid'] for t in trials.trials]
ys = [t['misc']['vals']['dropout1'] for t in trials.trials]
ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$dropout$ $vs$ $time$ ', fontsize=18)
ax.set_xlabel('$time$', fontsize=16)
ax.set_ylabel('$dropout$', fontsize=16)

# %%
#dropout vs units

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['units1'] for t in trials.trials]
ys = [t['misc']['vals']['dropout1'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$dropout$ $vs$ $units$ ', fontsize=18)
ax.set_xlabel('$units$', fontsize=16)
ax.set_ylabel('$dropout$', fontsize=16)

# %%
#value vs units

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['units1'] for t in trials.trials]
ys = [-t['result']['loss'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$accuracy$ $vs$ $units$ ', fontsize=18)
ax.set_xlabel('$units$', fontsize=16)
ax.set_ylabel('$accuracy$', fontsize=16)

# %%
#value vs dropout

f, ax = plt.subplots(1)
xs = [t['misc']['vals']['dropout1'] for t in trials.trials]
ys = [-t['result']['loss'] for t in trials.trials]
#ax.set_xlim(xs[0]-10, xs[-1]+10)
ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
ax.set_title('$accuracy$ $vs$ $dropout$ ', fontsize=18)
ax.set_xlabel('$dropout$', fontsize=16)
ax.set_ylabel('$accuracy$', fontsize=16)

# %% [markdown]
# #<font color='red'>**Optuna MNIST optimalization**

# %%
"""
Optuna example that optimizes a neural network classifier configuration for the
MNIST dataset using Keras.
In this example, we optimize the validation accuracy of MNIST classification using
Keras. We optimize the filter and kernel size, kernel stride and layer activation.
"""
! pip install optuna

import warnings

from keras.backend import clear_session
from keras.datasets import mnist
from keras.layers import Dense, Dropout
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop

import optuna

# %%
# Reduce the size of a dataset to speed the training up
N_TRAIN_EXAMPLES = 3000
N_VALID_EXAMPLES = 1000
BATCHSIZE = 128
CLASSES = 10
EPOCHS = 20

# %%
(x_train, y_train), (x_valid, y_valid) = mnist.load_data()

x_train = x_train.reshape(60000, 784)[:N_TRAIN_EXAMPLES].astype("float32") / 255
x_valid = x_valid.reshape(10000, 784)[:N_VALID_EXAMPLES].astype("float32") / 255
y_train = y_train[:N_TRAIN_EXAMPLES]
y_valid = y_valid[:N_VALID_EXAMPLES]

# %%
def objective(trial):

    # Clear clutter from previous Keras session graphs.
    clear_session()

    units = int(trial.suggest_discrete_uniform("units1", 32,3*1024,32))
    dropout = trial.suggest_uniform('dropout1', .00,.50)
    act = trial.suggest_categorical('activation', ['relu','sigmoid','linear'])
    lr = trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True)

    model = Sequential()
    model.add(Dense(units, activation=act, input_shape=(784,)))
    model.add(Dropout(dropout))
    model.add(Dense(units, activation=act))
    model.add(Dropout(dropout))
    model.add(Dense(units, activation=act))
    model.add(Dropout(dropout))

    model.add(Dense(CLASSES, activation="softmax"))

    # We compile our model with a sampled learning rate.
    model.compile(
        loss="sparse_categorical_crossentropy", optimizer=RMSprop(learning_rate=lr), metrics=["accuracy"]
    )

    model.fit(
        x_train,
        y_train,
        validation_data=(x_valid, y_valid),
        shuffle=True,
        batch_size=BATCHSIZE,
        epochs=epochs,
        verbose=False,
    )

    # Evaluate the model accuracy on the validation set.
    score = model.evaluate(x_valid, y_valid, verbose=0)
    return score[1]

# %% [markdown]
# # Find the best parameters

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100, timeout=600)

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

# %% [markdown]
# ## Visualizing the Optimization History

# %%
from optuna.visualization import plot_optimization_history

plot_optimization_history(study)

# %% [markdown]
# ## Visualizing High-dimensional Parameter Relationships

# %%
from optuna.visualization import plot_parallel_coordinate

plot_parallel_coordinate(study)

# %% [markdown]
# ## Visualizing Parameter Relationships

# %%
from optuna.visualization import plot_contour

plot_contour(study)

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_contour(study, params=['units1', 'dropout1', 'learning_rate'])

# %% [markdown]
# ## Visualizing Individual Parameters

# %%
from optuna.visualization import plot_slice

plot_slice(study)

# %% [markdown]
# ### Selecting Parameters to Visualize

# %%
plot_slice(study, params=['units1', 'dropout1'])

# %% [markdown]
# ## Visualizing Parameter Importances

# %%
from optuna.visualization import plot_param_importances

plot_param_importances(study)

# %% [markdown]
# #<font color='red'>**Keras tuner MNIST optimalization**

# %%
"""
Keras tuner example that optimizes a neural network classifier configuration for the
MNIST dataset using Keras.
"""

! pip install keras_tuner

import warnings

from keras.backend import clear_session
from keras.datasets import mnist
from keras.layers import Dense, Dropout
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop

import keras_tuner as kt

# %%
N_TRAIN_EXAMPLES = 3000
N_VALID_EXAMPLES = 1000
BATCHSIZE = 128
CLASSES = 10
EPOCHS = 20

# %% [markdown]
# #**Read MNIST data**

# %%
# Clear clutter from previous Keras session graphs.
clear_session()

(x_train, y_train), (x_valid, y_valid) = mnist.load_data()

x_train = x_train.reshape(60000, 784)[:N_TRAIN_EXAMPLES].astype("float32") / 255
x_valid = x_valid.reshape(10000, 784)[:N_VALID_EXAMPLES].astype("float32") / 255
y_train = y_train[:N_TRAIN_EXAMPLES]
y_valid = y_valid[:N_VALID_EXAMPLES]

# %% [markdown]
# #**Build model depending on hyperparameters *kt.HyperParameters()***

# %%
'''
    # This are parameters optimized by optuna, we do the same below
    units = int(trial.suggest_discrete_uniform("units1", 32,1024,1))
    dropout = trial.suggest_uniform('dropout1', .00,.50)
    act = trial.suggest_categorical('activation', ['relu','sigmoid','linear'])
    lr = trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True)
'''

def build_model(hp):

    units=hp.Int("units", min_value=32, max_value=3*1024, step=32)
    dropout=hp.Float('dropout', 0.00, 0.50)
    act=hp.Choice('activation', ['relu','sigmoid','linear'])
    lr = hp.Float("learning_rate", 1e-5, 1e-1, sampling='log')

    model = Sequential()
    model.add(Dense(units=units, activation=act, input_shape=(784,)))
    model.add(Dropout(rate=dropout))
    model.add(Dense(units=units, activation=act))
    model.add(Dropout(rate=dropout))
    model.add(Dense(units=units, activation=act))
    model.add(Dropout(rate=dropout))

    model.add(Dense(CLASSES, activation="softmax"))

    # We compile our model with a sampled learning rate.
    model.compile(
        loss="sparse_categorical_crossentropy", optimizer=RMSprop(learning_rate=lr), metrics=["accuracy"]
    )

    return model

build_model(kt.HyperParameters())

# %% [markdown]
# #**Prepare the search space**

# %%
#select a tuner class to run the search. You may choose from RandomSearch, BayesianOptimization
# and Hyperband, which correspond to different tuning algorithms.

tuner = kt.BayesianOptimization(
    hypermodel = build_model,
    objective="val_accuracy",
    max_trials=30
)

tuner.search_space_summary()

# %% [markdown]
# # **Find the best parameters**

# %%
epochs=20
tuner.search(x_train, y_train, epochs=epochs, validation_data=(x_valid, y_valid))

# %% [markdown]
# #**Get best model**

# %%
# Get the top 2 models.
models = tuner.get_best_models(num_models=2)
best_model = models[0]
# Build the model.
best_model.build()
best_model.summary()

# %% [markdown]
# # Print a summary of the 10 best search results

# %%
tuner.results_summary()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# #<font color='green'>**Summary**
#
# <span style="color:#000000"> __We have learned today how to optimize the hyperparameters\!__ </span>
#
# Very usefull for any training!

# %% [markdown]
# #**Bibliography:**
#
# <span style="color:#000000">Brochu\, E\.\, Cora\, V\. M\.\, and De Freitas\, N\. \(2010\)\. A tutorial on bayesian optimization of expensive cost functions\, with application to active user modeling and hierarchical reinforcement learning\. arXiv preprint arXiv:1012\.2599\.</span>
#
# <span style="color:#000000">Shahriari\, B\.\, Swersky\, K\.\, Wang\, Z\.\, Adams\, R\. P\.\, and de Freitas\, N\. \(2016\)\. Taking the human out of the loop: A review of bayesian optimization\. Proceedings of the IEEE\, 104\(1\):148–175\.</span>
#
# <span style="color:#000000">**Nice tutorial:**</span>
#
# <span style="color:#000000">[https://www\.iro\.umontreal\.ca/~bengioy/cifar/NCAP2014\-summerschool/slides/Ryan\_adams\_140814\_bayesopt\_ncap\.pdf](https://www.iro.umontreal.ca/~bengioy/cifar/NCAP2014-summerschool/slides/Ryan_adams_140814_bayesopt_ncap.pdf)</span>

# %% [markdown]
# # <font color = green> **Topics we try to cover in the next TWO lectures:**
# (but there is a little time...)
#
# * GAN - generative adversary network (maybe short)
# * Autoencoders - like PCA but non-linear
# * Stable diffusion generation (very popular for image generation)
# * Reinforcement learning RL - how to train a robot?

# %% [markdown]
# # <font color = green> **Topics we will not cover:**
# (because of little time...)
#
# * Cluster analysis,
# * Bayesian learning and Mixture Density Networks - a network (or a set of networks) returns probability distribution rather than an output in the form of numbers,
# * recurrent networks, long short-term memory LSTM networks,
# * language models, ChatGPT,
# * and many others.
